# %%
pip list
# Out:
# Package                                           Version
# ------------------------------------------------- ------------
# afnumpy                                           1.3
# aiofiles                                          0.6.0
# appnope                                           0.1.2
# argon2-cffi                                       21.1.0
# arrayfire                                         3.6.20181017
# attrs                                             21.2.0
# audio2numpy                                       0.1.2
# Automat                                           20.2.0
# backcall                                          0.2.0
# BeautifulRequests                                 0.2
# beautifulsoup4                                    4.9.3
# bleach                                            4.0.0
# cached-url                                        0.0.33
# certifi                                           2021.5.30
# ...
